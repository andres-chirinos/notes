# %%
# Loaded variable 'df' from URI: /home/andreschirinos/Proyectos/Bo1/Bo1/1. Cursos y Apuntes/Programación Avanzada/time.csv
import pandas as pd
df = pd.read_csv(r'/home/andreschirinos/Proyectos/Bo1/Bo1/1. Cursos y Apuntes/Programación Avanzada/time.csv')

# %%
# %pip install matplotlib
import matplotlib.pyplot as plt

# Seleccionamos las columnas de interés para el gráfico
cols = ['Bubble', 'Shell', 'Insertion', 'Selection', 'Quick']

# Graficamos usando el índice del dataframe como eje x (vector i)
df[cols].plot(marker='o')

plt.xlabel('Índice del vector')
plt.ylabel('Tiempo de ejecución')
plt.title('Tiempo de ejecución de cada algoritmo')
plt.legend(title='Algoritmos')
plt.show()
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
